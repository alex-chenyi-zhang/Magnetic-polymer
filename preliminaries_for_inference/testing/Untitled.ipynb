# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
E = np.loadtxt("energies_100.txt")
R = np.loadtxt("RG2_100.txt")
M = np.loadtxt("magnetization_100.txt")

# %%
plt.plot(E)

# %%
plt.figure(figsize=(9,6))
plt.plot(R[25000:])
plt.grid()
plt.ylabel("Squared gyaration radius")
plt.xlabel("MC steps")
plt.title("400 monomers. beta = 0.8")
#plt.savefig("rg_400_0.800_MMC.png")
# Out:
# Text(0.5, 1.0, '400 monomers. beta = 0.8')

# %%
np.mean(R[200000:])
# Out:
# 41.922886438

# %%
20*128**(1.11)
# Out:
# 4365.490645851941

# %%
plt.figure(figsize=(9,6))
plt.plot(M)
plt.grid()
plt.ylabel("Magnetization per spin")
plt.xlabel("MC steps")
plt.title("400 monomers. beta = 0.8")
#plt.savefig("mag_400_0.800_MMC.png")
# Out:
# Text(0.5, 1.0, '400 monomers. beta = 0.8')
