# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
E = np.loadtxt("energies_600.txt")
R = np.loadtxt("e2e_dist_600.txt")
M = np.loadtxt("magnetization_600.txt")

# %%
plt.plot(E)

# %%
plt.plot(np.sqrt(R[100:]))

# %%
np.mean(np.sqrt(R[200000:]))
# Out:
# 22.725404124862106

# %%
20*128**(1.11)
# Out:
# 4365.490645851941

# %%
plt.plot(M)
